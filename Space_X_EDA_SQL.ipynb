# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install ibm-db-sa
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip install SQLAlchemy
# !pip install ipython-sql

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %reload_ext sql

# %% [markdown]
# **DB2 magic in case of  UI service credentials.**
#
#
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width="600">
#
# * Use the following format.
#
# * Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL**

# %%
# %sql ibm_db_sa://kmy92432:qZdnQgURhdu7bvxn@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb?security=SSL
# Out:
# Traceback (most recent call last):
#   File "c:\Users\16194\anaconda3\lib\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "c:\Users\16194\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py", line 277, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "c:\Users\16194\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 556, in create_engine
#     entrypoint = u._get_entrypoint()
#   File "c:\Users\16194\anaconda3\lib\site-packages\sqlalchemy\engine\url.py", line 754, in _get_entrypoint
#     cls = registry.load(name)
#   File "c:\Users\16194\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 363, in load
#     return impl.load()
#   File "c:\Users\16194\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 194, in load
#     module = import_module(match.group('module'))
# ...

# %%
import ibm_db
import pandas
import ibm_db_dbi

# %%
dsn_hostname = "b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "kmy92432"        # e.g. "abc12345"
dsn_pwd = "qZdnQgURhdu7bvxn"      # e.g. "7dBZ3wWt9XN6$o0J"
dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "bludb"            # e.g. "BLUDB"
dsn_port = "31249"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %%
#Create database connection
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  bludb as user:  kmy92432 on host:  b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
query='Select * from spacex'

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf.head(10)
# Out:
#          DATE  TIME_UTC BOOSTER_VERSION  LAUNCH_SITE  \
# 0  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5  2013-09-29  16:00:00  F9 v1.1  B1003  VAFB SLC-4E
# 6  2013-12-03  22:41:00         F9 v1.1  CCAFS LC-40
# 7  2014-01-06  22:06:00         F9 v1.1  CCAFS LC-40
# 8  2014-04-18  19:25:00         F9 v1.1  CCAFS LC-40
# 9  2014-07-14  15:15:00         F9 v1.1  CCAFS LC-40
#
#                                              PAYLOAD  PAYLOAD_MASS_KG_  \
# 0               Dragon Spacecraft Qualification Unit                 0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                 0
# 2                              Dragon demo flight C2               525
# 3                                       SpaceX CRS-1               500
# ...

# %%
query='Select distinct (launch_site) from spacex'

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#     LAUNCH_SITE
# 0   CCAFS LC-40
# 1  CCAFS SLC-40
# 2    KSC LC-39A
# 3   VAFB SLC-4E

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
query="SELECT * FROM SPACEX WHERE LAUNCH_SITE LIKE 'CCA%' LIMIT 5"

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#          DATE  TIME_UTC BOOSTER_VERSION  LAUNCH_SITE  \
# 0  2010-06-04  18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  2010-12-08  15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  2012-05-22   7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  2012-10-08   0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  2013-03-01  15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              PAYLOAD  PAYLOAD_MASS_KG_  \
# 0               Dragon Spacecraft Qualification Unit                 0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                 0
# 2                              Dragon demo flight C2               525
# 3                                       SpaceX CRS-1               500
# 4                                       SpaceX CRS-2               677
#
#        ORBIT         CUSTOMER MISSION_OUTCOME      LANDING_OUTCOME
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
query="SELECT sum(PAYLOAD_MASS_KG_) FROM SPACEX WHERE CUSTOMER = 'NASA (CRS)'"

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#        1
# 0  45596

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
query="""SELECT AVG(PAYLOAD_MASS_KG_) AS "Average Payload Mass by NASA (CRS)" FROM SPACEX WHERE BOOSTER_VERSION = 'F9 v1.1'"""


stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#    Average Payload Mass by NASA (CRS)
# 0                                2928

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
query="""SELECT MIN(DATE) AS "First Succesful Landing Outcome in Ground Pad" FROM SPACEX WHERE LANDING_OUTCOME = 'Success (ground pad)'"""

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#   First Succesful Landing Outcome in Ground Pad
# 0                                    2015-12-22

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
query="SELECT BOOSTER_VERSION from spacex where LANDING_OUTCOME = 'Success (drone ship)'  and PAYLOAD_MASS_KG_ between 4000 and 6000 "

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#   BOOSTER_VERSION
# 0     F9 FT B1022
# 1     F9 FT B1026
# 2  F9 FT  B1021.2
# 3  F9 FT  B1031.2

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
import pandas as pd
query1="""SELECT COUNT(MISSION_OUTCOME) AS "Count Mission" FROM SPACEX WHERE MISSION_OUTCOME LIKE 'Success%'"""

stm=ibm_db.exec_immediate(conn, query1)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf1 = pandas.read_sql(query1, pconn)

query2="""SELECT COUNT(MISSION_OUTCOME) AS "Count Mission" FROM SPACEX WHERE MISSION_OUTCOME LIKE '%ailure%'"""

stm=ibm_db.exec_immediate(conn, query2)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf2 = pandas.read_sql(query2, pconn)
pdf=pd.concat([pdf1,pdf2])
pdf['Label']=['Success','Failure']
pdf
# Out:
#    Count Mission    Label
# 0            100  Success
# 0              1  Failure

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
query="SELECT DISTINCT BOOSTER_VERSION FROM SPACEX WHERE PAYLOAD_MASS_KG_ =(SELECT MAX(PAYLOAD_MASS_KG_) FROM SPACEX)"

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#    BOOSTER_VERSION
# 0    F9 B5 B1048.4
# 1    F9 B5 B1048.5
# 2    F9 B5 B1049.4
# 3    F9 B5 B1049.5
# 4    F9 B5 B1049.7
# 5    F9 B5 B1051.3
# 6    F9 B5 B1051.4
# 7    F9 B5 B1051.6
# 8    F9 B5 B1056.4
# 9    F9 B5 B1058.3
# 10   F9 B5 B1060.2
# 11   F9 B5 B1060.3

# %% [markdown]
# ### Task 9
#
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %%
query="SELECT LEFT(DATE,4) FROM SPACEX"

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#         1
# 0    2010
# 1    2010
# 2    2012
# 3    2012
# 4    2013
# ..    ...
# 96   2020
# 97   2020
# 98   2020
# 99   2020
# 100  2020
#
# [101 rows x 1 columns]

# %%
query="SELECT BOOSTER_VERSION LAUNCH_SITE, LANDING_OUTCOME FROM SPACEX WHERE LEFT(DATE,4)= 2015 AND LANDING_OUTCOME = 'Failure (drone ship)'"

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#      LAUNCH_SITE       LANDING_OUTCOME
# 0  F9 v1.1 B1012  Failure (drone ship)
# 1  F9 v1.1 B1015  Failure (drone ship)

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %%
query="SELECT LANDING_OUTCOME,COUNT(LANDING_OUTCOME) FROM SPACEX WHERE DATE BETWEEN '2010-06-04' AND '2017-03-20' \
GROUP BY  LANDING_OUTCOME \
ORDER BY COUNT(LANDING_OUTCOME) DESC ; "

stm=ibm_db.exec_immediate(conn, query)
ibm_db.fetch_both(stm)

pconn = ibm_db_dbi.Connection(conn)
pdf = pandas.read_sql(query, pconn)
pdf
# Out:
#           LANDING_OUTCOME   2
# 0              No attempt  10
# 1    Failure (drone ship)   5
# 2    Success (drone ship)   5
# 3      Controlled (ocean)   3
# 4    Success (ground pad)   3
# 5     Failure (parachute)   2
# 6    Uncontrolled (ocean)   2
# 7  Precluded (drone ship)   1
